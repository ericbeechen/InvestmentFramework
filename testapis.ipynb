# %%
import fredapi

# %%
import openbb

# %%
from ResearchViews import ResearchViews
from Universe import Universe

# %%
universe_builder = Universe()
universe = universe_builder.construct_universe()
# Out:
# Building universe of assets...

# %%
research_views = ResearchViews()

# %%
research_views.new_views(universe)
# Out:
#                      A        AAPL        ABBV        ABNB         ABT  \
# Date
# 2021-04-07  124.905960  124.574028   86.888611  179.940002  109.624130
# 2021-04-08  126.209686  126.970062   87.623634  180.179993  109.322960
# 2021-04-09  127.387886  129.541397   88.812881  179.500000  110.345184
# 2021-04-12  126.769821  127.827194   89.399223  176.490005  110.472961
# 2021-04-13  128.411514  130.934189   89.374458  177.949997  112.270973
# ...                ...         ...         ...         ...         ...
# 2026-03-31  113.980003  253.789993  217.490005  126.279999  102.669998
# 2026-04-01  114.540001  255.630005  214.979996  125.190002  102.379997
# 2026-04-02  115.480003  255.919998  208.839996  124.949997  102.870003
# 2026-04-06  114.839996  258.859985  206.690002  126.809998  102.300003
# 2026-04-07  114.090103  251.470001  205.279999  124.779999  102.820000
#
#                  ACGL         ACN        ADBE         ADI        ADM  ...  \
# ...
